# %%
import pickle 
import matplotlib.pyplot as plt
import numpy as np

# %%
durations = np.linspace(0,10,20)

# %%
peaks_a = [42.727975845336914, 62.96886444091797, 83.20425701141357, 103.44509220123291, 123.68042469024658, 143.92142868041992, 164.1567621231079, 184.3974905014038, 204.63309860229492, 224.87372207641602, 245.10916423797607, 265.34994316101074, 285.5853910446167, 305.82617473602295, 326.0616731643677, 346.30245208740234, 366.5380058288574, 386.7787895202637, 407.01412200927734, 427.2496757507324]
peaks_b = [111.65533351898193, 194.17220211029053, 220.2759199142456, 359.1990852355957, 385.30280685424805, 411.4134178161621, 437.51713943481445, 689.2527503967285, 715.3564720153809, 741.4670829772949, 767.5707540512085, 793.6814155578613, 819.7851371765137, 845.8957481384277, 871.9994697570801, 898.1100807189941, 1375.4638023376465, 1401.5744132995605, 1427.6780834197998, 1453.7815837860107]

durations = np.linspace(0,10,20)
plt.figure()
plt.plot(durations, peaks_b,'s-')
plt.plot(durations, peaks_a,'s-')
plt.xlabel('Sample Duration (s)')
plt.ylabel('Peak RAM usage (MB)')
# Out:
# Text(0, 0.5, 'Peak RAM usage (MB)')

# %%
peaks_a = [21.365344047546387, 42.72814083099365, 64.09071254730225, 85.45345401763916, 106.81614017486572, 128.17893600463867, 149.54162216186523, 170.9043083190918, 192.26699447631836, 213.62968063354492]
peaks_b =   [56.06331825256348, 111.65539169311523, 167.24735641479492, 222.8393211364746, 278.4312343597412, 334.02323055267334, 389.6152458190918, 445.2071533203125, 500.7991247177124, 556.3910245895386]

nfreqs = ([50,100,150,200,250,300,350,400,450,500])
plt.figure()
plt.plot(nfreqs, peaks_b,'s-')
plt.plot(nfreqs, peaks_a,'s-')
plt.xlabel('Number of Scales')
plt.ylabel('Peak RAM usage (MB)')
# Out:
# Text(0, 0.5, 'Peak RAM usage (MB)')
